# %% [markdown]
# <a href="https://colab.research.google.com/github/praveer-k/BMC-UI/blob/main/TinyLlama_Method1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !CMAKE_ARGS=" -DLLAMA_CUBLAS=on" pip install llama-cpp-python -q
# !CMAKE_ARGS="-DLLAMA_BLAS=ON -DLLAMA_BLAS_VENDOR=OpenBLAS" pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 MB 12.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.9-cp311-cp311-linux_x86_64.whl size=4127098 sha256=e337bc1e04bb0ec5309a35159b1bd021d551c064ce00beb67f4348e1dddae5b8
#   Stored in directory: /root/.cache/pip/wheels/9e/8f/bf/148c8eb7d69021eccd6eae6444f3accd48347587054ffd24e5
# Successfully built llama-cpp-python
# ...

# %%
# !pip3 install huggingface-hub

# %%
# !huggingface-cli download TheBloke/TinyLlama-1.1B-Chat-v1.0-GGUF \
tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf \
--local-dir . \
--local-dir-use-symlinks False
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf: 100% 669M/669M [00:02<00:00, 243MB/s]
# Download complete. Moving file to tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf
# tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf

# %%
from llama_cpp import Llama

# %%
llm = Llama(model_path="./tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf",
            n_ctx=2048,
            n_threads=8,
            n_gpu_layers=35)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from ./tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = tinyllama_tinyllama-1.1b-chat-v1.0
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 5632
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 64
# ...

# %%
# ./tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf
llm = Llama(model_path="./tiny-merged-v2.gguf", chat_format="llama-2")
# Out:
# llama_model_loader: loaded meta data with 31 key-value pairs and 201 tensors from ./tiny-merged-v2.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Tinyllama Merged
# llama_model_loader: - kv   3:                         general.size_label str              = 1.1B
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# llama_model_loader: - kv   5:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   6:                     llama.embedding_length u32              = 2048
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
llm.create_chat_completion(
      messages = [
        {
          "role": "system",
          "content": "You are expert on OECD Transfer Pricing Guidelines for Multinational Enterprises and Tax Administrations January 2022"

        },
        {
          "role": "user",
          "content": "How do we avoid and resolve transfer pricing disputes?"
        }
      ]
)
# Out:
# Llama.generate: 32 prefix-match hit, remaining 27 prompt tokens to eval
